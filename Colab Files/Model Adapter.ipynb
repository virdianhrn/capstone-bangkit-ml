# %%
# !gdown --folder "1Og_yc4GS8umbO-gdX8IjsIatycsKgqJz"
# Out:
# Retrieving folder list
# Retrieving folder 1-8D09z5bEQ47VYX8RH5VCLYWwfA-Tnv2 Bias
# Retrieving folder 1rAaMGl2p-HUqPsEOQnXTb4bAJz8p0T11 BV1
# Retrieving folder 1-6UncV5W-GE0ielW4yVEJB5Uh1TpqNfM assets
# Processing file 1-4ypQ4uaj4zpI2ipzWVDgSFL77V6XmR- fingerprint.pb
# Processing file 1-4TphECxRLiIojmrokNm2r_rCgfQPpiH keras_metadata.pb
# Processing file 1-68qD1yQzzRyCmezwidbME2qjNch5JM1 saved_model.pb
# Retrieving folder 1-1-NCwlS6aotS3XJ_l5K-que5H4n5-jW variables
# Processing file 1-1LdTiVOwkZNltoyWtvg95D_j20hN0K3 variables.data-00000-of-00001
# Processing file 1-858eXwo1TGut8b6XGZqyH1DRAs4Ep-L variables.index
# Processing file 1fxa-bHdyPA4r1SMhz8yYkpO6mj5gyUxP BV1.png
# Retrieving folder 1xF4py4fpJkiWmlEa2-BgKALRH-5jTt3h Neutrality
# Retrieving folder 1lISuw3lfLZVQqvBwJKBvILlN8uPwivCV NV1
# Retrieving folder 1-pq_PG1zXAQbYMbLp7oFEcWq-xYc0dG8 assets
# Processing file 1-fnzFd9cE5sslxR3BiLwKzD_zXz6JOy6 fingerprint.pb
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import tensorflow as tf
import shutil, os

# %%
subjectivity_model = tf.keras.models.load_model('Model/Subjectivity/SV2')
subjectivity_model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ...
#  input_ids (InputLayer)      [(None, 512)]                0         []
#
#  attention_mask (InputLayer  [(None, 512)]                0         []
#  )
#
#  bert (Custom>TFBertMainLay  {'last_hidden_state': (Non   1105582   ['input_ids[0][0]',
#  er)                         e, 512, 768),                08         'attention_mask[0][0]']
#                               'pooler_output': (None, 7
#                              68)}
#
#  sequential (Sequential)     (None, 1)                    206177    ['bert[0][1]']
#
# ...
# Total params: 110764385 (422.53 MB)
# Trainable params: 110764385 (422.53 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
subjectivity_model.save('/content/drive/MyDrive/Capstone/Model/Subjectivity/SV2.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
bias_model = tf.keras.models.load_model('Model/Bias/BV1')
bias_model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ...
#  input_ids (InputLayer)      [(None, 256)]                0         []
#
#  attention_mask (InputLayer  [(None, 256)]                0         []
#  )
#
#  bert (Custom>TFBertMainLay  {'last_hidden_state': (Non   1105582   ['input_ids[0][0]',
#  er)                         e, 256, 768),                08         'attention_mask[0][0]']
#                               'pooler_output': (None, 7
#                              68)}
#
#  sequential_1 (Sequential)   (None, 1)                    206177    ['bert[0][1]']
#
# ...
# Total params: 110764385 (422.53 MB)
# Trainable params: 110764385 (422.53 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
# EXPORT_PATH_BIAS = 'gs://sinari-raw-model/export/BV1'
bias_model.save('/content/drive/MyDrive/Capstone/Model/Bias/BV1.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
neutrality_model = tf.keras.models.load_model('/content/drive/MyDrive/Capstone/Model/Neutrality/NV1')
neutrality_model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ...
#  input_ids (InputLayer)      [(None, 256)]                0         []
#
#  attention_mask (InputLayer  [(None, 256)]                0         []
#  )
#
#  bert (Custom>TFBertMainLay  {'last_hidden_state': (Non   1105582   ['input_ids[0][0]',
#  er)                         e, 256, 768),                08         'attention_mask[0][0]']
#                               'pooler_output': (None, 7
#                              68)}
#
#  sequential_1 (Sequential)   (None, 3)                    25763     ['bert[0][1]']
#
# ...
# Total params: 110583971 (421.84 MB)
# Trainable params: 110583971 (421.84 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
# EXPORT_PATH_NETR = 'gs://sinari-raw-model/export/NV1'
neutrality_model.save('/content/drive/MyDrive/Capstone/Model/Neutrality/NV1.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
